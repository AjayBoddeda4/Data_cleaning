# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession .\
builder .\
appName("spark") .\
config("spark.sql.warehouse.dir","/user/itv016843/warehouse") .\
enableHiveSupport() .\
master("yarn") .\
getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://g02.itversity.com:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql.functions import *

# %%
from pyspark.sql import *

# %%
df1 = spark.read \
.format("csv") \
.option("header",True) \
.load("/user/itv016843/loan_data.csv")

# %%
df1.limit(5)
# Out:
# +--------+---------+---------+-----------+---------------+----------+--------+-----------+-----+---------+--------------------+----------+--------------+----------+-------------------+--------+-----------+----------+--------------------+----+------------------+------------------+--------+----------+-----+-----------+----------------+--------------+---------------+--------------+----------------------+----------------------+--------+-------+---------+----------+---------+-------------------+---------+-------------+------------------+---------------+---------------+-------------+------------------+----------+-----------------------+------------+---------------+------------+------------------+--------------------+-------------------+--------------------------+---------------------------+-----------+----------------+----------------+---------+-------------------------+--------------+------------+-----------+-----------+-----------+-----------+-----------+------------------+------------+-
# ...

# %% [raw]
# # As this is the finance data member_id is imp column in this data but member_id is not there so i created the member_id using sha and concat_ws

# %%
df2 = df1.withColumn("new_table",sha2(concat_ws("|",*["emp_title","emp_length","home_ownership","zip_code","addr_state","annual_inc","grade","sub_grade","verification_status"]),256))

# %%
df2.limit(5)
# Out:
# +--------+---------+---------+-----------+---------------+----------+--------+-----------+-----+---------+--------------------+----------+--------------+----------+-------------------+--------+-----------+----------+--------------------+----+------------------+------------------+--------+----------+-----+-----------+----------------+--------------+---------------+--------------+----------------------+----------------------+--------+-------+---------+----------+---------+-------------------+---------+-------------+------------------+---------------+---------------+-------------+------------------+----------+-----------------------+------------+---------------+------------+------------------+--------------------+-------------------+--------------------------+---------------------------+-----------+----------------+----------------+---------+-------------------------+--------------+------------+-----------+-----------+-----------+-----------+-----------+------------------+------------+-
# ...

# %%
df2.createOrReplaceTempView("data")

# %%
spark.sql("use ajdb1")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables")
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |        |     data|       true|
# +--------+---------+-----------+

# %%
spark.sql("select new_table,member_id from data").limit(5)
# Out:
# +--------------------+---------+
# |           new_table|member_id|
# +--------------------+---------+
# |475b8e55adad369e9...|     null|
# |4e5fbf219649d2fc1...|     null|
# |da69c56b4b9466307...|     null|
# |f6469465a44523a0a...|     null|
# |6df065a87c2c4668a...|     null|
# +--------------------+---------+

# %%
df2.limit(3)
# Out:
# +--------+---------+---------+-----------+---------------+----------+--------+-----------+-----+---------+------------+----------+--------------+----------+-------------------+--------+-----------+----------+--------------------+----+------------------+------------------+--------+----------+-----+-----------+----------------+--------------+---------------+--------------+----------------------+----------------------+--------+-------+---------+----------+---------+-------------------+---------+-------------+------------------+---------------+---------------+-------------+------------------+----------+-----------------------+------------+---------------+------------+------------------+--------------------+-------------------+--------------------------+---------------------------+-----------+----------------+----------------+---------+-------------------------+--------------+------------+-----------+-----------+-----------+-----------+-----------+------------------+------------+-------+-
# ...

# %% [markdown]
# # later i have selected the columns which are necessart for my customers_data,loans_data,loan_defaulters,loan_repayments

# %%
spark.sql("select new_table as member_id ,emp_title,emp_length,home_ownership,zip_code,addr_state,application_type,annual_inc,annual_inc_joint from data").repartition(1) \
.write \
.format("csv") \
.mode("overwrite") \
.option("header",True) \
.option("path","/user/itv016843/cleaned/cust_data") \
.save()

# %%
check = spark.read \
.format("csv") \
.option("header",True) \
.load("/user/itv016843/cleaned/*")

# %%
check.limit(5)
# Out:
# +--------------------+--------------------+----------+--------------+--------+----------+----------------+----------+----------------+
# |           member_id|           emp_title|emp_length|home_ownership|zip_code|addr_state|application_type|annual_inc|annual_inc_joint|
# +--------------------+--------------------+----------+--------------+--------+----------+----------------+----------+----------------+
# |475b8e55adad369e9...|             leadman| 10+ years|      MORTGAGE|   190xx|        PA|      Individual|   55000.0|            null|
# |4e5fbf219649d2fc1...|            Engineer| 10+ years|      MORTGAGE|   577xx|        SD|      Individual|   65000.0|            null|
# |da69c56b4b9466307...|        truck driver| 10+ years|      MORTGAGE|   605xx|        IL|       Joint App|   63000.0|         71000.0|
# |f6469465a44523a0a...|Information Syste...| 10+ years|      MORTGAGE|   076xx|        NJ|      Individual|  110000.0|            null|
# ...
